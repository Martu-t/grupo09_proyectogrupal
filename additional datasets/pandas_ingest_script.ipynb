# %%
import pandas as pd

# %%
volcano_data = pd.read_csv('C:/Users/FedeGP/OneDrive/Escritorio/volcano.tsv', delimiter='\t', skiprows=[1])

# %%
volcano_data.head()
# Out:
#    Search Parameters  Year  Mo    Dy     Tsu      Eq              Name  \
# 0                NaN  2010   1   NaN     NaN     NaN        Tungurahua
# 1                NaN  2010   3  31.0     NaN     NaN  Eyjafjallajokull
# 2                NaN  2010   5  27.0     NaN     NaN            Pacaya
# 3                NaN  2010   5  29.0  4822.0  9172.0    Zealandia Bank
# 4                NaN  2010   8   6.0     NaN     NaN       Karangetang
#
#                Location        Country  Latitude  ...  Total Deaths  \
# 0               Ecuador        Ecuador    -1.467  ...           NaN
# 1             Iceland-S        Iceland    63.633  ...           2.0
# 2             Guatemala      Guatemala    14.382  ...           1.0
# 3  Mariana Is-C Pacific  United States    16.880  ...           NaN
# 4  Sangihe Is-Indonesia      Indonesia     2.781  ...           4.0
#
#    Total Death Description Total Missing  Total Missing Description  \
# ...

# %%
tsunami_data = pd.read_csv('C:/Users/FedeGP/OneDrive/Escritorio/tsunami.tsv', delimiter='\t', skiprows=[1])

# %%
tsunami_data.head()
# Out:
#    Search Parameters  Year  Mo  Dy    Hr    Mn   Sec  Tsunami Event Validity  \
# 0                NaN  2010   1   2   NaN   NaN   NaN                       2
# 1                NaN  2010   1   3  21.0  48.0   5.3                       4
# 2                NaN  2010   1   3  22.0  36.0  27.9                       4
# 3                NaN  2010   1   5  12.0  15.0  32.2                       4
# 4                NaN  2010   1  12  21.0  53.0  10.0                       4
#
#    Tsunami Cause Code  Earthquake Magnitude  ...  Total Missing  \
# 0                   9                   NaN  ...            NaN
# 1                   1                   6.6  ...            NaN
# 2                   1                   7.1  ...            NaN
# 3                   1                   6.8  ...            NaN
# 4                   3                   7.0  ...            NaN
#
#    Total Missing Description  Total Injuries Total Injuries Description  \
# ...

# %%
earthquake_data = pd.read_csv('C:/Users/FedeGP/OneDrive/Escritorio/tsunami.tsv', delimiter='\t', skiprows=[1])

# %%
earthquake_data.head()
# Out:
#    Search Parameters  Year  Mo  Dy    Hr    Mn   Sec  Tsunami Event Validity  \
# 0                NaN  2010   1   2   NaN   NaN   NaN                       2
# 1                NaN  2010   1   3  21.0  48.0   5.3                       4
# 2                NaN  2010   1   3  22.0  36.0  27.9                       4
# 3                NaN  2010   1   5  12.0  15.0  32.2                       4
# 4                NaN  2010   1  12  21.0  53.0  10.0                       4
#
#    Tsunami Cause Code  Earthquake Magnitude  ...  Total Missing  \
# 0                   9                   NaN  ...            NaN
# 1                   1                   6.6  ...            NaN
# 2                   1                   7.1  ...            NaN
# 3                   1                   6.8  ...            NaN
# 4                   3                   7.0  ...            NaN
#
#    Total Missing Description  Total Injuries Total Injuries Description  \
# ...
