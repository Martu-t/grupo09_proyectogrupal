# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../../../DATA_analysis_ML.csv')
pd.set_option('display.max_columns', None)
data.drop(columns='Unnamed: 0', inplace=True)
data.head()

# %%
data.head()
# Out:
#            id   mag                           place                     time  \
# 0  ci38692706  0.11  14km SSW of Searles Valley, CA   2020-09-17 04:32:55.79
# 1  us6000bzp0  4.10      61 km SW of Palana, Russia  2020-09-17 04:29:22.603
# 2  us6000bzpa  4.40    52 km WSW of F?r?z?b?d, Iran  2020-09-17 04:29:05.818
# 3  mb80463974  2.07      27 km NW of Stanley, Idaho   2020-09-17 04:26:28.89
# 4  nc73459001  0.34   12km ENE of Mammoth Lakes, CA   2020-09-17 04:22:27.47
#
#                    updated  felt  cdi  mmi    status  tsunami  sig net  \
# 0  2020-09-22 15:38:31.987   NaN  NaN  NaN  reviewed        0    0  ci
# 1   2020-11-28 21:31:47.04   NaN  NaN  NaN  reviewed        0  259  us
# 2   2020-11-28 21:31:47.04   NaN  NaN  NaN  reviewed        0  298  us
# 3   2020-09-17 14:20:04.83   NaN  NaN  NaN  reviewed        0   66  mb
# 4   2020-09-17 05:49:03.75   NaN  NaN  NaN  reviewed        0    2  nc
#
#        code           ids sources  \
# 0  38692706  ,ci38692706,    ,ci,
# 1  6000bzp0  ,us6000bzp0,    ,us,
# 2  6000bzpa  ,us6000bzpa,    ,us,
# 3  80463974  ,mb80463974,    ,mb,
# 4  73459001  ,nc73459001,    ,nc,
#
#                                             types  nst     dmin   rms    gap  \
# 0  ,nearby-cities,origin,phase-data,scitech-link,    8  0.06373  0.15  149.0
# 1                             ,origin,phase-data,    1  0.15400  0.53  116.0
# 2                             ,origin,phase-data,    1  0.15400  0.38   74.0
# 3                             ,origin,phase-data,    9  0.15400  0.22   77.0
# 4  ,nearby-cities,origin,phase-data,scitech-link,   12  0.02699  0.06  146.0
#
#   magType        type         lon        lat  depth  dist  cluster  signif
# 0      ml  earthquake -117.459667  35.650333  10.00    14        1     NaN
# 1      mb  earthquake  159.176300  58.701100  10.00    61        3     NaN
# 2      mb  earthquake   52.077000  28.649900  10.00    52        3     NaN
# 3      ml  earthquake -115.219833  44.356833  14.66    27        1     NaN
# 4      md  earthquake -118.851833  37.661833  10.00    12        1     NaN

# %%
sns.scatterplot(x = data['dist'], y = data['mag'], hue = data['cluster'], legend ='full')
plt.title('Dataset 2')
plt.show()

# %%
sns.scatterplot(x = data['depth'], y = data['mag'], hue = data['cluster'], legend ='full')
plt.title('Dataset 2')
plt.show()

# %%
signif = data[data['signif']==1]

# %%
fig, ax = plt.subplots()
sns.histplot(x=signif['cluster'], binwidth=1)
ax.set_xlim(-1,5)
ax.set_xticks(range(0,4))
plt.show()
